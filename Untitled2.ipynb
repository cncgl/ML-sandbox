# %%
# %load_ext sql
# Out:
# /home/shigeru/.anyenv/envs/pyenv/versions/miniconda3-3.19.0/lib/python3.5/site-packages/IPython/config.py:13: ShimWarning: The `IPython.config` package has been deprecated. You should import from traitlets.config instead.
#   "You should import from traitlets.config instead.", ShimWarning)
# /home/shigeru/.anyenv/envs/pyenv/versions/miniconda3-3.19.0/lib/python3.5/site-packages/IPython/utils/traitlets.py:5: UserWarning: IPython.utils.traitlets has moved to a top-level traitlets package.
#   warn("IPython.utils.traitlets has moved to a top-level traitlets package.")

# %%
# %sql postgresql://
# Out:
# Format: (postgresql|mysql)://username:password@hostname/dbname, or one of dict_keys(['sqlite://', 'None@None'])
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-8-e4f10d709fa5> in <module>()
# ----> 1 get_ipython().magic('sql postgresql://')
#       2
#
# /home/shigeru/.anyenv/envs/pyenv/versions/miniconda3-3.19.0/lib/python3.5/site-packages/IPython/core/interactiveshell.py in magic(self, arg_s)
#    2334         magic_name, _, magic_arg_s = arg_s.partition(' ')
#    2335         magic_name = magic_name.lstrip(prefilter.ESC_MAGIC)
# -> 2336         return self.run_line_magic(magic_name, magic_arg_s)
#    2337
#    2338     #-------------------------------------------------------------------------
#
# /home/shigeru/.anyenv/envs/pyenv/versions/miniconda3-3.19.0/lib/python3.5/site-packages/IPython/core/interactiveshell.py in run_line_magic(self, magic_name, line)
# ...

# %%
# %%sql postgresql://postgres:postgres@localhost/sample_dev
#         select * from todos
# Out:
# Format: (postgresql|mysql)://username:password@hostname/dbname, or one of dict_keys(['sqlite://', 'None@None'])
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-10-a42411c97a9a> in <module>()
# ----> 1 get_ipython().run_cell_magic('sql', 'postgresql://postgres:postgres@localhost/sample_dev', '        select * from todos')
#
# /home/shigeru/.anyenv/envs/pyenv/versions/miniconda3-3.19.0/lib/python3.5/site-packages/IPython/core/interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2291             magic_arg_s = self.var_expand(line, stack_depth)
#    2292             with self.builtin_trap:
# -> 2293                 result = fn(magic_arg_s, cell)
#    2294             return result
#    2295
#
# <decorator-gen-124> in execute(self, line, cell, local_ns)
#
# ...
